# %% [markdown]
# <a href="https://colab.research.google.com/github/tjahjoe/PCVK-Genap-25-26/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/image/train/19.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/image/train/19.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Tugas

# %% [markdown]
# 1.  Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# jawab: dengan menggunakan figsize ukuran pixel gambar akan tetap

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
img = cv.imread('/content/drive/MyDrive/image/train/19.jpeg')
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

img_rb = img3.copy()
img_rb[:, :, 1] = 0

img_gb = img3.copy()
img_gb[:, :, 0] = 0

plt.imshow(img_rb)
plt.show()
plt.imshow(img_gb)
plt.show()

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
img_crop = img3[20:115, 25:120]
plt.imshow(img_crop)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
img_r = img3.copy()
img_r[:, :, 1] = 0
img_r[:, :, 2] = 0

img_r = img_r[5:30, :, :]
plt.imshow(img_r)

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=-1)
cv.rectangle(black_img, pt1=(0, 0), pt2=(110, 150), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=-1)
cv.rectangle(black_img, pt1=(0, 200), pt2=(100, 300), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=-1)
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=-1)
cv.rectangle(black_img, pt1=(400, 400), pt2=(510, 510), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=-1)
plt.imshow(black_img)

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

img_flip = cv.flip(black_img, 0)
plt.imshow(img_flip)

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
img = cv.imread('/content/André_Onana.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img, pt1=(1000, 750), pt2=(1750, 2000), color=(np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256)), thickness=10)
cv.circle(img, center=(1400,1400), radius=300, color=(255,0,0), thickness=8)
plt.imshow(img)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
img = cv.imread('/content/Lenna.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
print(img.shape[0])
cv.rectangle(img, pt1=(10, 400), pt2=(100, 502), color=(0,255,0), thickness=12)
plt.imshow(img)
# Out:
# 512

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img, text='lena', org=(200,500), fontFace=font, fontScale=4, color=(100,100,100), thickness=2, lineType=cv.LINE_AA)
plt.imshow(img)
