# %% [markdown]
# <a href="https://colab.research.google.com/github/tjahjoe/PCVK-Genap-25-26/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
urls = ['https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg',
        'https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg',
        'https://akcdn.detik.net.id/visual/2025/03/06/ilustrasi-kucing-bulu-pendek-british-shorthair-1741229753892_11.jpeg?w=720&q=90'
        ]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=720x360>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  360  x  360
# <PIL.Image.Image image mode=RGB size=360x360>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)
for y in range(lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=720x360>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# jawab: karena dengan menggunakan google colab banyak library untuk image processing yang sudah terinstall juga terdapat gpu gratis akan tetapi memiliki limit
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# jawab:
# - numpy: Operasi numerik dan array multidimensi
# - pandas: Manipulasi data tabular
# - cv2: Pengolahan gambar dan video
# - google.colab.patches: Integrasi dengan Google Colab untuk menampilkan gambar
# - skimage: Analisis dan pemrosesan gambar
# - PIL: Manipulasi gambar
# - matplotlib: Visualisasi data dan gambar
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program. Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# jawab: untuk memberikan perubahan ukuran dengan setengah ukuran gambar diawal dan agar pemrosesan lebih cepat juga penggunaan memori lebih rendah
#
# 4. Perhatikan potongan kode progam. Apakah kegunaan kode [255,255,255] ? Jelaskan!
# jawab: untuk memberikan warna putih pada titik tersebut, karena menggunakan looping jadi akan membuat titik-titik menjadi garis
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# jawab: jika gambar resolusi tinggi akan memiliki pixel yang banyak, begitupun sebaliknya

# %% [markdown]
# Tugas

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
  image_3[x, int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=720x360>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]
    image_3[i, lebar - 1 - i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=720x360>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(120, 250):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=720x360>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(120, 250):
  for x in range(120, 250):
    image_3[x, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=720x360>
